# %% [markdown]
# # [Global 88] Gender Violence in Colombia
# ### Professor: Karenjot Bhangoo Randhawa
# **Estimated Time:** 50 minutes
# **Notebook Created By:** Carlos Calderon
# **Code Maintenance:** Carlos Calderon
#
# <div class="alert alert-block alert-danger">
# <b>Trigger Warning:</b> The topic and datasets we will be talking about on this notebook deal with sensitive issues around sexual assault, domestic violence, physical violence, and gender-based discrimination. We acknowledge that the content may be difficult to work with. Please, feel free to take a break whenever you need it. If you'd like to skip this assignment, please let the course staff now.
# </div>
#
# Welcome! Last week we got an introduction to data types and the visualizations we can conduct with them. This week, we will expand more on table operations and visualization topics that we introduced in the first and second notebooks. This week, however, we will be dealing with a dataset regarding gender violence accross Colombia. This week we will take a look at a primary, sex-dissagregated dataset. Next week we will look at a secondary, non sex-dissagregated data.
#
# **Learning Outcomes:**
# BY the end of this notebook, students will be able to:
# 1. Understand the differences between sex-dissagregated and non sex-dissagregated data
# 2. Understand the insights we can derive from a sex-dissagregated data
#
# # Table of Contents
# 1. The Data
# 2. Comparisons

# %% [markdown]
# # Importing Packages
#
# <div class="alert alert-block alert-warning">
# <b>Maker sure to run this cell FIRST! Not doing so may result in pesky errors in the code.</b>
# </div>

# %%
from datascience import *
import numpy as np

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# # 1. The Data
# Our data comes from the [Colombia National Police](https://www.policia.gov.co/grupo-informacion-criminalidad/estadistica-delictiva) database, which contains yearly information on different crime categories accross Colombia. The dataset we will be working with describes statistics on intrafamilial violence from 2015 to 2021. Intrafamilial violence is [defined as any act punishable as a criminal offense that is committed or threatened to be committed by an offender who is related to the victim, or has a child with the victim.](https://www.ncsl.org/research/human-services/domestic-violence-domestic-abuse-definitions-and-relationships.aspx#:~:text=(9)%20%22Intrafamily%20violence%22,has%20a%20child%20in%20common.) Run the cell below to load the dataset onto the variable `family_violence`.

# %%
family_violence = Table.read_table("../data/nb3/domestic_violence_colombia_police.csv")
family_violence.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>State</th> <th>City</th> <th>Gender</th> <th>Weapon Used</th> <th>Affected Age Group</th> <th>Total</th> <th>Year</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Amazonas</td> <td>Leticia (Ct)</td> <td>Female</td> <td>Sharp weapon      </td> <td>Teenagers         </td> <td>1    </td> <td>2015</td>
#         </tr>
#         <tr>
#             <td>Amazonas</td> <td>Leticia (Ct)</td> <td>Female</td> <td>Sharp weapon      </td> <td>Adult             </td> <td>1    </td> <td>2015</td>
#         </tr>
#         <tr>
#             <td>Amazonas</td> <td>Leticia (Ct)</td> <td>Female</td> <td>Blunt force weapon</td> <td>Teenagers         </td> <td>6    </td> <td>2015</td>
#         </tr>
#         <tr>
#             <td>Amazonas</td> <td>Leticia (Ct)</td> <td>Female</td> <td>Blunt force weapon</td> <td>Adult             </td> <td>100  </td> <td>2015</td>
#         </tr>
#         <tr>
#             <td>Amazonas</td> <td>Leticia (Ct)</td> <td>Female</td> <td>Blunt force weapon</td> <td>Minors            </td> <td>3    </td> <td>2015</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (39970 rows omitted)</p>

# %% [markdown]
# ## 1.1 Understanding the Data

# %% [markdown]
# Although the column names are clear, it still is useful to create a mapping between column names and what they represent.
#
# | Column (Variable) Name | Description                          |
# |------------------------|--------------------------------------|
# | State                  | Name of State                        |
# | City                   | Name of City                         |
# | Gender                 | Gender of the victim                 |
# | Weapon Used            | Weapon used by the perpetrator       |
# | Affected Age Group     | Age group that the victim belongs to |
# | Total                  | Total number of crimes in the area   |
# | Year                   | Year                                 |
#
# The rest of this section will focus on questions that will guide you in truly understanding the dataset. Whenever you start an individual project with a new dataset, it is extremely useful to start asking yourself these questions. The answers will guide your future analysis and will give you a better idea of what insights you can expect to find.

# %% [markdown]
# <div class="alert alert-info">
# <b> Question 1.1: </b> With the name and meaning of our dataset's columns in mind, what does each row in our dataset represent?
# </div>

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# <div class="alert alert-info">
#     <b> Question 1.2: </b> Using the table properties <code>num_columns</code> and <code>num_rows</code> that we learned in Notebook 1, fill in the code below to print out the size of our dataset.
# </div>

# %%
family_violence_num_rows = family_violence... # Assign this to the number of rows in our dataset
family_violence_num_columns = family_violence... # Assign this to the number of columns in our dataset
print(f"Our dataset has {family_violence_num_rows} rows and {family_violence_num_columns} columns.")
# Out:
#   File "<ipython-input-6-0b6be388414b>", line 1
#     family_violence_num_rows = family_violence... # Assign this to the number of rows in our dataset
#                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-info">
#     <b> Question 1.3: </b> If you had no information about the source of the dataset or the information it contained, how would you use the number of rows and columns and what they each represent to build your intuition on what the dataset is describing?
# </div>

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# <div class="alert alert-info">
#     <b> Question 1.4: </b> Fill in the blanks below with the names of the columns that contain categorical data. If you need more or less space, feel free to add or delete a bullet point.
# </div>

# %% [markdown]
# - ...
# - ...
# - ...
# - ...

# %% [markdown]
# <div class="alert alert-info">
#     <b> Question 1.5: </b> Fill in the blanks below with the names of the columns that contain numerical data.
# </div>

# %% [markdown]
# - ...
# - ...
# - ...
# - ...

# %% [markdown]
# ## 1.2 Barplots - One Categorical Variable
#
# Last week we went over data types and their visualizations. So far, we have seen the following set of relationships:
#
# | Variable/s                     | Visualization |
# |--------------------------------|---------------|
# | numeric                        | Histogram     |
# | numeric x numeric              | Scatter plot  |
# | numeric x numeric (sequential) | Line plot     |
#
# In this section we will be going over **barplots**. Barplots are useful in visualizing both number of groups and the number of times a group appears within a single categorical variable. For example, our `family_violence` dataset contains several categorical variables, one of them being `Affected Age Group`. In this case, `Affected Age Group` is a categorical variable, but how many groups does this variable contain? This question can be answered with a bar plot.

# %%
from collections import Counter

# %%
affected_age_group = family_violence.column("Affected Age Group")
affected_age_group_counts = Counter(affected_age_group)

# Plotting code
plt.bar(affected_age_group_counts.keys(), affected_age_group_counts.values(), 
        color="b", edgecolor="dodgerblue");

plt.xlabel("Age Group")
plt.ylabel("Number Affected")
plt.title("Number Affected per Age Group")
# Out:
# Text(0.5, 1.0, 'Number Affected per Age Group')

# %%
women_affected_age_groups = family_violence.where("Gender", "Female")
men_affected_age_groups = family_violence.where("Gender", "Male")

# %%
def bar_plot_gender(col_name, ylabel):
    
    counts = Counter(family_violence.column(col_name))

    women = family_violence.where("Gender", "Female")
    men = family_violence.where("Gender", "Male")
    
    women_counts = Counter(women.column(col_name))
    men_counts = Counter(men.column(col_name))
    
    women_percents = np.array(list(women_counts.values())) / sum(women_counts.values())
    men_percents = np.array(list(men_counts.values())) / sum(men_counts.values())
    
    bar_width = 0.25
    br1 = np.arange(1, len(counts.keys()) + 1).tolist()
    br2 = [x + bar_width for x in br1]
    
    plt.bar(br1, 
        women_percents,
        width = bar_width,
        color='r', 
        label="Women")
    
    plt.bar(br2, 
        men_percents,
        width = bar_width,
        color="b", 
        label="Men")
    
    plt.xticks(np.arange(1, len(counts.keys()) + 1).tolist(),
           counts.keys())
    
    plt.xlabel(col_name)
    plt.ylabel(ylabel)
    plt.title(col_name + " by Gender")
    
    plt.xticks(rotation = 30)
    
    plt.legend();

# %%
bar_plot_gender("Affected Age Group", "Percentage Affected")

# %%
bar_plot_gender("Weapon Used", "Percentage Used")

# %%
city = family_violence.column("City")
city_counts = Counter(city)
city_counts
# Out:
# Counter({'Leticia (Ct)': 87,
#          'Puerto Nariño': 34,
#          'Abejorral': 34,
#          'Abriaquí': 4,
#          'Alejandría': 28,
#          'Amagá': 49,
#          'Amalfi': 47,
#          'Andes': 75,
#          'Angelópolis': 33,
#          'Angostura': 34,
#          'Anorí': 39,
#          'Anza': 21,
#          'Apartadó': 101,
#          'Arboletes': 23,
#          'Argelia': 70,
#          'Armenia': 26,
#          'Barbosa': 167,
#          'Bello': 131,
#          'Belmira': 13,
#          'Betania': 43,
#          'Betulia': 60,
#          'Briceño': 41,
#          'Buriticá': 16,
#          'Caicedo': 17,
#          'Caldas': 106,
#          'Campamento': 39,
#          'Caracolí': 14,
#          'Caramanta': 11,
#          'Carepa': 61,
#          'Carolina': 20,
#          'Caucasia': 92,
#          'Cañasgordas': 19,
#          'Chigorodó': 55,
#          'Cisneros': 41,
#          'Ciudad Bolívar': 61,
#          'Cocorná': 56,
#          'Concepción': 32,
#          'Concordia': 65,
#          'Copacabana': 84,
#          'Cáceres': 30,
#          'Dabeiba': 21,
#          'Don Matías': 48,
#          'Ebéjico': 32,
#          'El Bagre': 47,
#          'El Carmen De Viboral': 73,
#          'El Santuario': 52,
#          'Entrerrios': 16,
#          'Envigado': 98,
#          'Fredonia': 62,
#          'Frontino': 44,
#          'Giraldo': 14,
#          'Girardota': 60,
#          'Granada': 146,
#          'Guadalupe': 85,
#          'Guarne': 66,
#          'Guatapé': 30,
#          'Gómez Plata': 36,
#          'Heliconia': 20,
#          'Hispania': 37,
#          'Itagui': 114,
#          'Ituango': 32,
#          'Jardín': 24,
#          'Jericó': 66,
#          'La Ceja': 56,
#          'La Estrella': 91,
#          'La Pintada': 35,
#          'La Unión': 149,
#          'Liborina': 17,
#          'Maceo': 26,
#          'Marinilla': 48,
#          'Medellín (Ct)': 171,
#          'Montebello': 18,
#          'Mutatá': 35,
#          'Nariño': 67,
#          'Nechí': 27,
#          'Necoclí': 38,
#          'Peque': 8,
#          'Peñol': 27,
#          'Pueblorrico': 29,
#          'Puerto Berrío': 87,
#          'Puerto Nare': 33,
#          'Puerto Triunfo': 46,
#          'Remedios': 42,
#          'Retiro': 38,
#          'Rionegro': 149,
#          'Sabanalarga': 104,
#          'Sabaneta': 86,
#          'Salgar': 38,
#          'San Andrés De Cuerquía': 27,
#          'San Carlos': 51,
#          'San Francisco': 65,
#          'San Jerónimo': 29,
#          'San José De La Montaña': 16,
#          'San Juan De Urabá': 23,
#          'San Luis': 58,
#          'San Pedro': 127,
#          'San Pedro De Urabá': 30,
#          'San Rafael': 19,
#          'San Roque': 38,
#          'San Vicente': 43,
#          'Santa Bárbara': 59,
#          'Santa Rosa De Osos': 46,
#          'Santafé De Antioquia': 48,
#          'Santo Domingo': 33,
#          'Segovia': 53,
#          'Sonson': 57,
#          'Sopetrán': 31,
#          'Tarazá': 44,
#          'Tarso': 34,
#          'Titiribí': 27,
#          'Toledo': 31,
#          'Turbo': 76,
#          'Támesis': 36,
#          'Uramita': 13,
#          'Urrao': 43,
#          'Valdivia': 29,
#          'Valparaíso': 40,
#          'Vegachí': 27,
#          'Venecia': 45,
#          'Vigía Del Fuerte': 8,
#          'Yalí': 21,
#          'Yarumal': 84,
#          'Yolombó': 43,
#          'Yondó': 46,
#          'Zaragoza': 44,
#          'Arauca (Ct)': 99,
#          'Arauquita': 46,
#          'Cravo Norte': 12,
#          'Fortul': 26,
#          'Puerto Rondón': 11,
#          'Saravena': 83,
#          'Tame': 86,
#          'Baranoa': 38,
#          'Barranquilla (Ct)': 168,
#          'Campo De La Cruz': 16,
#          'Candelaria': 102,
#          'Galapa': 60,
#          'Juan De Acosta': 14,
#          'Luruaco': 42,
#          'Malambo': 69,
#          'Manatí': 26,
#          'Palmar De Varela': 26,
#          'Piojó': 8,
#          'Polonuevo': 12,
#          'Ponedera': 24,
#          'Puerto Colombia': 74,
#          'Repelón': 26,
#          'Sabanagrande': 42,
#          'Santa Lucía': 8,
#          'Santo Tomás': 20,
#          'Soledad': 139,
#          'Suan': 8,
#          'Tubará': 21,
#          'Usiacurí': 13,
#          'Achí': 9,
#          'Altos Del Rosario': 5,
#          'Arenal': 10,
#          'Arjona': 56,
#          'Arroyohondo': 16,
#          'Barranco De Loba': 19,
#          'Calamar': 60,
#          'Cantagallo': 31,
#          'Cartagena (Ct)': 152,
#          'Cicuco': 21,
#          'Clemencia': 30,
#          'Córdoba': 61,
#          'El Carmen De Bolívar': 78,
#          'El Guamo': 23,
#          'Hatillo De Loba': 15,
#          'Magangué': 104,
#          'Mahates': 26,
#          'Margarita': 7,
#          'María La Baja': 57,
#          'Mompós': 45,
#          'Montecristo': 8,
#          'San Estanislao': 23,
#          'San Fernando': 10,
#          'San Jacinto': 35,
#          'San Juan Nepomuceno': 49,
#          'San Martín De Loba': 21,
#          'San Pablo': 61,
#          'Santa Catalina': 34,
#          'Santa Rosa': 63,
#          'Santa Rosa Del Sur': 50,
#          'Simití': 31,
#          'Talaigua Nuevo': 12,
#          'Tiquisio': 13,
#          'Turbaco': 68,
#          'Turbaná': 28,
#          'Villanueva': 168,
#          'Zambrano': 19,
#          'Almeida': 15,
#          'Aquitania': 36,
#          'Arcabuco': 29,
#          'Belén': 68,
#          'Boavita': 19,
#          'Boyacá': 28,
#          'Buenavista': 91,
#          'Busbanzá': 8,
#          'Campohermoso': 12,
#          'Cerinza': 20,
#          'Chinavita': 19,
#          'Chiquinquirá': 94,
#          'Chiscas': 12,
#          'Chita': 13,
#          'Chitaraque': 35,
#          'Chivor': 14,
#          'Chíquiza': 15,
#          'Ciénega': 18,
#          'Coper': 24,
#          'Covarachía': 7,
#          'Cubará': 20,
#          'Cucaita': 21,
#          'Cuítiva': 28,
#          'Cómbita': 27,
#          'Duitama': 121,
#          'El Cocuy': 18,
#          'El Espino': 7,
#          'Floresta': 14,
#          'Gachantivá': 20,
#          'Gameza': 27,
#          'Garagoa': 49,
#          'Guacamayas': 6,
#          'Guateque': 37,
#          'Guayatá': 18,
#          'Güicán': 11,
#          'Jenesano': 27,
#          'La Capilla': 20,
#          'Labranzagrande': 16,
#          'Macanal': 8,
#          'Maripí': 28,
#          'Miraflores': 67,
#          'Mongua': 10,
#          'Monguí': 19,
#          'Moniquirá': 50,
#          'Motavita': 24,
#          'Muzo': 41,
#          'Nobsa': 37,
#          'Nuevo Colón': 34,
#          'Oicatá': 21,
#          'Otanche': 29,
#          'Pachavita': 21,
#          'Paipa': 56,
#          'Panqueba': 13,
#          'Pauna': 26,
#          'Paya': 21,
#          'Paz De Río': 13,
#          'Pesca': 20,
#          'Puerto Boyacá': 86,
#          'Páez': 17,
#          'Quípama': 22,
#          'Ramiriquí': 44,
#          'Ráquira': 35,
#          'Saboyá': 38,
#          'Samacá': 44,
#          'San Eduardo': 12,
#          'San José De Pare': 30,
#          'San Luis De Gaceno': 19,
#          'San Mateo': 11,
#          'San Miguel De Sema': 15,
#          'San Pablo De Borbur': 26,
#          'Santa María': 38,
#          'Santa Rosa De Viterbo': 39,
#          'Santa Sofía': 31,
#          'Santana': 37,
#          'Sativanorte': 15,
#          'Siachoque': 29,
#          'Soatá': 35,
#          'Socha': 18,
#          'Socotá': 17,
#          'Sogamoso': 97,
#          'Somondoco': 9,
#          'Sora': 16,
#          'Soracá': 32,
#          'Sotaquirá': 30,
#          'Susacón': 13,
#          'Sutamarchán': 23,
#          'Sutatenza': 15,
#          'Sáchica': 27,
#          'Tasco': 19,
#          'Tenza': 12,
#          'Tibaná': 33,
#          'Tibasosa': 54,
#          'Tinjacá': 28,
#          'Toca': 19,
#          'Togüí': 29,
#          'Tota': 16,
#          'Tunja (Ct)': 116,
#          'Tununguá': 12,
#          'Turmequé': 36,
#          'Tuta': 23,
#          'Tópaga': 16,
#          'Umbita': 19,
#          'Ventaquemada': 44,
#          'Villa De Leyva': 51,
#          'Viracachá': 29,
#          'Zetaquira': 27,
#          'Aguadas': 42,
#          'Anserma': 69,
#          'Aranzazu': 29,
#          'Belalcázar': 26,
#          'Chinchiná': 102,
#          'Filadelfia': 21,
#          'La Dorada': 109,
#          'La Merced': 22,
#          'Manizales (Ct)': 130,
#          'Manzanares': 40,
#          'Marmato': 22,
#          'Marquetalia': 26,
#          'Neira': 40,
#          'Norcasia': 27,
#          'Palestina': 79,
#          'Pensilvania': 36,
#          'Pácora': 26,
#          'Riosucio': 97,
#          'Risaralda': 35,
#          'Salamina': 63,
#          'Samaná': 36,
#          'San José': 27,
#          'Supía': 53,
#          'Victoria': 27,
#          'Villamaría': 74,
#          'Viterbo': 35,
#          'Albania': 67,
#          'Belén De Los Andaquies': 30,
#          'Cartagena Del Chairá': 45,
#          'Curillo': 23,
#          'El Doncello': 42,
#          'El Paujil': 31,
#          'Florencia (Ct)': 128,
#          'La Montañita': 27,
#          'Milán': 13,
#          'Morelia': 13,
#          'Puerto Rico': 84,
#          'San José Del Fragua': 28,
#          'San Vicente Del Caguán': 55,
#          'Solano': 22,
#          'Solita': 12,
#          'Aguazul': 62,
#          'Chameza': 10,
#          'Hato Corozal': 24,
#          'Maní': 36,
#          'Monterrey': 69,
#          'Nunchía': 32,
#          'Orocué': 39,
#          'Paz De Ariporo': 82,
#          'Pore': 44,
#          'San Luis De Palenque': 24,
#          'Sácama': 1,
#          'Tauramena': 60,
#          'Trinidad': 36,
#          'Támara': 20,
#          'Yopal (Ct)': 119,
#          'Almaguer': 36,
#          'Balboa': 56,
#          'Bolívar': 106,
#          'Buenos Aires': 40,
#          'Cajibío': 58,
#          'Caldono': 33,
#          'Caloto': 70,
#          'Corinto': 50,
#          'El Tambo': 88,
#          'Florencia': 12,
#          'Guachené': 52,
#          'Guapi': 44,
#          'Inzá': 44,
#          'Jambaló': 11,
#          'La Sierra': 26,
#          'La Vega': 76,
#          'López': 15,
#          'Mercaderes': 37,
#          'Miranda': 52,
#          'Morales': 45,
#          'Padilla': 19,
#          'Paez': 35,
#          'Patía': 52,
#          'Piamonte': 16,
#          'Piendamó': 68,
#          'Popayán (Ct)': 158,
#          'Puerto Tejada': 74,
#          'Puracé': 25,
#          'Rosas': 29,
#          'San Sebastián': 14,
#          'Santander De Quilichao': 110,
#          'Silvia': 37,
#          'Sotara': 27,
#          'Suárez': 54,
#          'Timbiquí': 24,
#          'Timbío': 56,
#          'Toribio': 34,
#          'Totoró': 29,
#          'Villa Rica': 53,
#          'Aguachica': 100,
#          'Agustín Codazzi': 72,
#          'Becerril': 24,
#          'Bosconia': 45,
#          'Chimichagua': 20,
#          'Chiriguaná': 36,
#          'Curumaní': 45,
#          'El Copey': 35,
#          'El Paso': 30,
#          'Gamarra': 23,
#          'González': 14,
#          'La Jagua De Ibirico': 36,
#          'La Paz': 65,
#          'Manaure': 31,
#          'Pailitas': 30,
#          'Pelaya': 25,
#          'Pueblo Bello': 22,
#          'Río De Oro': 30,
#          'San Alberto': 46,
#          'San Diego': 28,
#          'San Martín': 95,
#          'Tamalameque': 20,
#          'Valledupar (Ct)': 140,
#          'Acandí': 25,
#          'Atrato': 12,
#          'Bagadó': 7,
#          'Bahía Solano': 36,
#          'Bajo Baudó': 9,
#          'Condoto': 32,
#          'El Carmen De Atrato': 21,
#          'Istmina': 47,
#          'Medio Atrato': 6,
#          'Medio Baudó': 11,
#          'Nuquí': 15,
#          'Quibdó (Ct)': 98,
#          'Tadó': 38,
#          'Unguía': 17,
#          'Unión Panamericana': 14,
#          'Agua De Dios': 35,
#          'Albán': 40,
#          'Anapoima': 41,
#          'Anolaima': 17,
#          'Apulo': 21,
#          'Arbeláez': 36,
#          'Beltrán': 9,
#          'Bogotá D.C. (Ct)': 228,
#          'Bojacá': 34,
#          'Cabrera': 44,
#          'Cachipay': 37,
#          'Cajicá': 52,
#          'Caparrapí': 21,
#          'Caqueza': 56,
#          'Carmen De Carupa': 25,
#          'Chipaque': 26,
#          'Choachí': 30,
#          'Chocontá': 45,
#          'Chía': 80,
#          'Cogua': 61,
#          'Cota': 46,
#          'Cucunubá': 26,
#          'El Colegio': 41,
#          'El Peñón': 45,
#          'El Rosal': 48,
#          'Facatativá': 114,
#          'Fomeque': 32,
#          'Fosca': 22,
#          'Funza': 85,
#          'Fusagasugá': 104,
#          'Fúquene': 23,
#          'Gachala': 18,
#          'Gachancipá': 50,
#          'Gachetá': 22,
#          'Gama': 18,
#          'Girardot': 116,
#          'Guachetá': 30,
#          'Guaduas': 44,
#          'Guasca': 43,
#          'Guataquí': 10,
#          'Guatavita': 25,
#          'Guayabal De Siquima': 12,
#          'Guayabetal': 12,
#          'Gutiérrez': 22,
#          'Jerusalén': 19,
#          'Junín': 14,
#          'La Calera': 55,
#          'La Mesa': 57,
#          'La Palma': 25,
#          'La Peña': 23,
#          'Lenguazaque': 26,
#          'Macheta': 19,
#          'Madrid': 77,
#          'Medina': 23,
#          'Mosquera': 89,
#          'Nemocón': 47,
#          'Nilo': 26,
#          'Nimaima': 14,
#          'Nocaima': 16,
#          'Pacho': 56,
#          'Paime': 12,
#          'Pandi': 19,
#          'Paratebueno': 20,
#          'Pasca': 31,
#          'Puerto Salgar': 48,
#          'Pulí': 10,
#          'Quebradanegra': 32,
#          'Quetame': 28,
#          'Quipile': 21,
#          'Ricaurte': 69,
#          'San Antonio Del Tequendama': 40,
#          'San Bernardo': 33,
#          'San Cayetano': 30,
#          'San Juan De Río Seco': 38,
#          'Sasaima': 25,
#          'Sesquilé': 31,
#          'Sibaté': 49,
#          'Silvania': 44,
#          'Simijaca': 32,
#          'Soacha': 152,
#          'Sopó': 37,
#          'Subachoque': 38,
#          'Suesca': 30,
#          'Supatá': 27,
#          'Susa': 22,
#          'Sutatausa': 25,
#          'Tabio': 34,
#          'Tausa': 22,
#          'Tena': 33,
#          'Tenjo': 47,
#          'Tibirita': 15,
#          'Tocaima': 46,
#          'Tocancipá': 64,
#          'Topaipí': 21,
#          'Ubalá': 21,
#          'Ubaque': 34,
#          'Une': 29,
#          'Vergara': 22,
#          'Vianí': 12,
#          'Villa De San Diego De Ubate': 72,
#          'Villagómez': 19,
#          'Villapinzón': 36,
#          'Villeta': 64,
#          'Viotá': 23,
#          'Yacopí': 19,
#          'Zipacón': 25,
#          'Zipaquirá': 105,
#          'Útica': 19,
#          'Ayapel': 32,
#          'Canalete': 15,
#          'Cereté': 65,
#          'Chinú': 59,
#          'Ciénaga De Oro': 32,
#          'Cotorra': 24,
#          'La Apartada': 29,
#          'Lorica': 72,
#          'Los Córdobas': 19,
#          'Momil': 27,
#          'Montelíbano': 61,
#          'Montería (Ct)': 133,
#          'Moñitos': 19,
#          'Planeta Rica': 74,
#          'Pueblo Nuevo': 45,
#          'Puerto Escondido': 25,
#          'Puerto Libertador': 49,
#          'Purísima': 35,
#          'Sahagún': 75,
#          'San Andrés Sotavento': 36,
#          'San Antero': 37,
#          'San Bernardo Del Viento': 29,
#          'San José De Uré': 12,
#          'San Pelayo': 34,
#          'Tierralta': 68,
#          'Tuchín': 34,
#          'Valencia': 21,
#          'Inírida (Ct)': 58,
#          'Barrancas': 30,
#          'Dibulla': 38,
#          'Distracción': 17,
#          'El Molino': 15,
#          'Fonseca': 37,
#          'Hatonuevo': 16,
#          'Maicao': 78,
#          'Riohacha (Ct)': 107,
#          'San Juan Del Cesar': 48,
#          'Uribia': 28,
#          'Urumita': 12,
#          'El Retorno': 25,
#          'San José Del Guaviare (Ct)': 99,
#          'Acevedo': 56,
#          'Agrado': 33,
#          'Aipe': 41,
#          'Algeciras': 46,
#          'Altamira': 15,
#          'Baraya': 22,
#          'Campoalegre': 49,
#          'Colombia': 20,
#          'Elías': 16,
#          'Garzón': 95,
#          'Gigante': 56,
#          'Hobo': 29,
#          'Isnos': 51,
#          'La Argentina': 23,
#          'La Plata': 68,
#          'Neiva (Ct)': 134,
#          'Nátaga': 13,
#          'Oporapa': 35,
#          'Paicol': 22,
#          'Palermo': 38,
#          'Pital': 44,
#          'Pitalito': 97,
#          'Rivera': 43,
#          'Saladoblanco': 24,
#          'San Agustín': 65,
#          'Suaza': 33,
#          'Tarqui': 33,
#          'Tello': 39,
#          'Teruel': 21,
#          'Tesalia': 31,
#          'Timaná': 51,
#          'Villavieja': 27,
#          'Yaguará': 29,
#          'Algarrobo': 24,
#          'Aracataca': 47,
#          'Ariguaní': 23,
#          'Cerro San Antonio': 10,
#          'Chibolo': 20,
#          'Ciénaga': 80,
#          'El Banco': 61,
#          'El Piñon': 20,
#          'El Retén': 26,
#          'Fundación': 75,
#          'Guamal': 71,
#          'Nueva Granada': 14,
#          'Pijiño Del Carmen': 13,
#          'Pivijay': 41,
#          'Plato': 53,
#          'Puebloviejo': 26,
#          'Sabanas De San Angel': 10,
#          'San Sebastián De Buenavista': 17,
#          'Santa Ana': 23,
#          'Santa Bárbara De Pinto': 17,
#          'Santa Marta (Ct)': 161,
#          'Sitionuevo': 23,
#          'Tenerife': 12,
#          'Zona Bananera': 48,
#          'Acacías': 101,
#          'Barranca De Upía': 24,
#          'Cabuyaro': 30,
#          'Castilla La Nueva': 34,
#          'Cubarral': 30,
#          'Cumaral': 61,
#          'El Calvario': 11,
#          'El Castillo': 28,
#          'El Dorado': 20,
#          'Fuente De Oro': 36,
#          'La Macarena': 33,
#          'Lejanías': 26,
#          'Mapiripán': 32,
#          'Mesetas': 33,
#          'Puerto Concordia': 23,
#          'Puerto Gaitán': 61,
#          'Puerto Lleras': 32,
#          'Puerto López': 52,
#          'Restrepo': 74,
#          'San Carlos De Guaroa': 38,
#          'San Juan De Arama': 30,
#          'San Juanito': 5,
#          'Uribe': 21,
#          'Villavicencio (Ct)': 161,
#          'Vistahermosa': 41,
#          'Aldana': 19,
#          'Ancuyá': 12,
#          'Barbacoas': 32,
#          'Buesaco': 41,
#          'Chachagüí': 31,
#          'Consaca': 19,
#          'El Charco': 19,
#          'El Rosario': 16,
#          'El Tablón De Gómez': 19,
#          'Funes': 8,
#          'Guachucal': 13,
#          'Guaitarilla': 22,
#          'Gualmatán': 10,
#          'Iles': 15,
#          'Imués': 23,
#          'Ipiales': 90,
#          'La Cruz': 27,
#          'La Florida': 19,
#          'La Llanada': 12,
#          'Leiva': 18,
#          'Linares': 14,
#          'Mallama': 16,
#          'Ospina': 13,
#          'Pasto (Ct)': 155,
#          'Policarpa': 29,
#          'Potosí': 31,
#          'Pupiales': 18,
#          'Samaniego': 29,
#          'San Andres De Tumaco': 97,
#          'Sandoná': 33,
#          'Santacruz': 13,
#          'Sapuyes': 13,
#          'Taminango': 27,
#          'Tangua': 32,
#          'Túquerres': 50,
#          'Yacuanquer': 26,
#          'Abrego': 33,
#          'Arboledas': 19,
#          'Bochalema': 17,
#          'Bucarasica': 8,
#          'Cachirá': 10,
#          'Chinácota': 34,
#          'Chitagá': 20,
#          'Convención': 16,
#          'Cucutilla': 21,
#          'Cácota': 12,
#          'Cúcuta (Ct)': 174,
#          'Durania': 15,
#          'El Carmen': 15,
#          'El Tarra': 13,
#          'El Zulia': 42,
#          'La Playa': 17,
#          'Labateca': 3,
#          'Los Patios': 81,
#          'Lourdes': 12,
#          'Mutiscua': 12,
#          'Ocaña': 95,
#          'Pamplona': 57,
#          'Pamplonita': 13,
#          'Puerto Santander': 25,
#          'Ragonvalia': 18,
#          'Salazar': 17,
#          'Sardinata': 33,
#          'Silos': 13,
#          'Teorama': 19,
#          'Tibú': 71,
#          'Villa Caro': 11,
#          'Villa Del Rosario': 87,
#          'Colón': 25,
#          'Mocoa (Ct)': 81,
#          'Orito': 41,
#          'Puerto Asís': 82,
#          'Puerto Caicedo': 27,
#          'Puerto Guzmán': 22,
#          'Puerto Leguízamo': 47,
#          'San Miguel': 34,
#          'Santiago': 22,
#          'Sibundoy': 42,
#          'Valle Del Guamuez': 44,
#          'Villagarzón': 52,
#          'Armenia (Ct)': 138,
#          'Calarca': 87,
#          'Circasia': 36,
#          'Filandia': 37,
#          'Génova': 31,
#          'La Tebaida': 54,
#          'Montenegro': 58,
#          'Pijao': 27,
#          'Quimbaya': 72,
#          'Salento': 36,
#          'Apía': 37,
#          'Belén De Umbría': 43,
#          'Dosquebradas': 122,
#          'Guática': 36,
#          'La Celia': 18,
#          'La Virginia': 86,
#          'Marsella': 37,
#          'Mistrató': 17,
#          'Pereira (Ct)': 144,
#          'Pueblo Rico': 29,
#          'Quinchía': 41,
#          'Santa Rosa De Cabal': 103,
#          'Santuario': 44,
#          'Providencia': 29,
#          'San Andrés (Ct)': 94,
#          'Aratoca': 21,
#          'Barichara': 26,
#          'Barrancabermeja': 142,
#          'Bucaramanga (Ct)': 154,
#          'California': 19,
#          'Capitanejo': 17,
#          'Cerrito': 20,
#          'Charalá': 28,
#          'Charta': 17,
#          'Chima': 16,
#          'Chipatá': 11,
#          'Cimitarra': 66,
#          'Confines': 18,
#          'Contratación': 22,
#          'Coromoro': 31,
#          'Curití': 31,
#          'El Carmen De Chucurí': 41,
#          'El Guacamayo': 19,
#          'El Playón': 41,
#          'Enciso': 12,
#          'Floridablanca': 134,
#          'Florián': 17,
#          'Galán': 25,
#          'Gambita': 28,
#          'Girón': 122,
#          'Guaca': 18,
#          'Guapotá': 14,
#          'Güepsa': 32,
#          'Hato': 15,
#          'Jesús María': 13,
#          'La Belleza': 22,
#          'Landázuri': 28,
#          'Lebrija': 69,
#          'Los Santos': 26,
#          'Matanza': 24,
#          'Mogotes': 44,
#          'Málaga': 39,
#          'Ocamonte': 33,
#          'Oiba': 42,
#          'Onzaga': 27,
#          'Palmar': 10,
#          'Palmas Del Socorro': 14,
#          'Piedecuesta': 115,
#          'Pinchote': 23,
#          'Puente Nacional': 44,
#          'Puerto Parra': 29,
#          'Puerto Wilches': 66,
#          'Páramo': 12,
#          'Sabana De Torres': 60,
#          'San Andrés': 20,
#          'San Benito': 9,
#          'San Gil': 82,
#          'San Joaquín': 17,
#          'San José De Miranda': 19,
#          'San Vicente De Chucurí': 68,
#          'Santa Helena Del Opón': 17,
#          'Simacota': 37,
#          'Socorro': 60,
#          'Suaita': 36,
#          'Sucre': 53,
#          'Suratá': 23,
#          'Tona': 20,
#          'Valle De San José': 27,
#          'Vetas': 14,
#          'Vélez': 45,
#          'Zapatoca': 29,
#          'Caimito': 16,
#          'Chalán': 9,
#          'Coloso': 30,
#          'Corozal': 90,
#          'Coveñas': 38,
#          'El Roble': 15,
#          'Galeras': 33,
#          'Guaranda': 21,
#          'Los Palmitos': 41,
#          'Majagual': 29,
#          'Morroa': 45,
#          'Ovejas': 38,
#          'Palmito': 18,
#          'Sampués': 65,
#          'San Benito Abad': 29,
#          'San Juan De Betulia': 34,
#          'San Luis De Sincé': 54,
#          'San Marcos': 62,
#          'San Onofre': 50,
#          'Santiago De Tolú': 80,
#          'Sincelejo (Ct)': 134,
#          'Tolú Viejo': 46,
#          'Alpujarra': 24,
#          'Alvarado': 43,
#          'Ambalema': 27,
#          'Anzoátegui': 27,
#          'Armero': 58,
#          'Ataco': 34,
#          'Cajamarca': 65,
#          'Carmen De Apicalá': 31,
#          'Casabianca': 16,
#          'Chaparral': 88,
#          'Coello': 32,
#          'Coyaima': 48,
#          'Cunday': 25,
#          'Dolores': 22,
#          'Espinal': 97,
#          'Falan': 25,
#          'Flandes': 56,
#          'Fresno': 38,
#          'Guamo': 53,
#          'Herveo': 14,
#          'Honda': 63,
#          'Ibagué (Ct)': 175,
#          'Icononzo': 38,
#          'Lérida': 47,
#          'Líbano': 64,
#          'Mariquita': 85,
#          'Melgar': 48,
#          'Murillo': 25,
#          'Natagaima': 38,
#          'Ortega': 50,
#          'Palocabildo': 18,
#          'Piedras': 25,
#          'Planadas': 34,
#          'Prado': 20,
#          'Purificación': 41,
#          'Rioblanco': 31,
#          'Roncesvalles': 19,
#          'Rovira': 62,
#          'Saldaña': 49,
#          'San Antonio': 37,
#          'Santa Isabel': 15,
#          'Valle De San Juan': 19,
#          'Venadillo': 30,
#          'Villahermosa': 18,
#          'Villarrica': 17,
#          'Alcalá': 32,
#          'Andalucía': 51,
#          'Ansermanuevo': 37,
#          'Buenaventura': 129,
#          'Bugalagrande': 47,
#          'Caicedonia': 56,
#          'Cali (Ct)': 187,
#          'Calima': 38,
#          'Cartago': 118,
#          'Dagua': 61,
#          'El Cairo': 23,
#          'El Cerrito': 60,
#          'El Dovio': 24,
#          'El Águila': 11,
#          'Florida': 61,
#          'Ginebra': 53,
#          'Guacarí': 60,
#          'Guadalajara De Buga': 125,
#          'Jamundí': 88,
#          'La Cumbre': 45,
#          'La Victoria': 54,
#          'Obando': 25,
#          'Palmira': 111,
#          'Pradera': 62,
#          'Riofrío': 39,
#          'Roldanillo': 62,
#          'Sevilla': 72,
#          'Toro': 25,
#          'Trujillo': 47,
#          'Tuluá': 108,
#          'Ulloa': 18,
#          'Vijes': 35,
#          'Yotoco': 43,
#          'Yumbo': 101,
#          'Zarzal': 80,
#          'Caruru': 11,
#          'Mitú (Ct)': 59,
#          'Cumaribo': 12,
#          'Puerto Carreño (Ct)': 43,
#          'Santa Rosalía': 15,
#          'Murindó': 6,
#          'Olaya': 11,
#          'Pinillos': 16,
#          'San Cristóbal': 16,
#          'Soplaviento': 21,
#          'Berbeo': 5,
#          'Betéitiva': 8,
#          'Chivatá': 14,
#          'Corrales': 12,
#          'Firavitoba': 21,
#          'Iza': 11,
#          'Pajarito': 31,
#          'Pisba': 3,
#          'Tutazá': 15,
#          'La Salina': 4,
#          'Recetor': 3,
#          'Astrea': 21,
#          'La Gloria': 23,
#          'Cértegui': 8,
#          'Bituima': 10,
#          'Chaguaní': 8,
#          'Manta': 13,
#          'Tibacuy': 22,
#          'Chimá': 24,
#          'Iquira': 31,
#          'Pedraza': 4,
#          'San Zenón': 15,
#          'Arboleda': 17,
#          'Contadero': 18,
#          'Cuaspud': 16,
#          'Cumbal': 18,
#          'Cumbitara': 18,
#          'El Peñol': 13,
#          'Francisco Pizarro': 11,
#          'Magüi': 5,
#          'Puerres': 17,
#          'San Lorenzo': 19,
#          'Gramalote': 4,
#          'Hacarí': 7,
#          'La Esperanza': 20,
#          'San Calixto': 3,
#          'Aguada': 7,
#          'Carcasí': 7,
#          'Encino': 6,
#          'Guavatá': 8,
#          'Macaravita': 11,
#          'Versalles': 17,
#          'Taraira': 14,
#          'La Primavera': 16,
#          'Regidor': 12,
#          'Río Viejo': 5,
#          'La Uvita': 10,
#          'Rondón': 12,
#          'Sativasur': 6,
#          'Tipacoque': 13,
#          'Marulanda': 8,
#          'El Litoral Del San Juan': 7,
#          'Juradó': 6,
#          'Lloró': 15,
#          'Medio San Juan': 8,
#          'Nóvita': 10,
#          ...})

# %%
plt.figure(figsize=(100, 50)) 
plt.bar(city_counts.keys(), np.array(list(city_counts.values())) / sum(city_counts.values()))
plt.xticks(rotation = 90)
plt.yticks(fontsize = 60)
plt.xlabel("City", fontsize = 60)
plt.ylabel("Percentage", fontsize = 60)
plt.show();

# %%
gender = family_violence.column("Gender")
gender_counts = Counter(gender)
gender_counts
# Out:
# Counter({'Female': 25697, 'Male': 14270, 'Not Reported': 8})

# %%
plt.bar(gender_counts.keys(), np.array(list(gender_counts.values())) / sum(gender_counts.values()))
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.show();

# %%
year = family_violence.column("Year")
year_counts = Counter(year)
year_counts
# Out:
# Counter({2015: 5007,
#          2016: 5362,
#          2017: 5846,
#          2018: 5918,
#          2019: 5488,
#          2020: 6760,
#          2021: 5594})

# %%
plt.bar(year_counts.keys(), np.array(list(year_counts.values())) / sum(year_counts.values()))
plt.xlabel("Year")
plt.ylabel("Percentage")
plt.show();
